# %%
# !pip install keras-unet-collection albumentations tensorflow==2.5.0 keras==2.5.0
DRIVE_PATH = "/content/drive/MyDrive/Datasets/Cell-Image-Segmentation/dataset_structured.zip"
# DRIVE_PATH = "/content/drive/MyDrive/Datasets/Cell-Image-Segmentation/split_data.zip"
# !unzip $DRIVE_PATH -d /content
# !pip install split-folders

# %%
import splitfolders
# !mkdir split_data
splitfolders.ratio(
    '/content/datasets/Neuroblastoma',
    '/content/split_data',
    seed=420,
    ratio=(.8, .2),
    group_prefix=None
)
# Out:
# Copying files: 36 files [00:00, 380.16 files/s]

# %%
# !pip install keras-unet-collection
# Out:
# Collecting keras-unet-collection
#   Using cached keras_unet_collection-0.1.11-py3-none-any.whl (67 kB)
# Installing collected packages: keras-unet-collection
# Successfully installed keras-unet-collection-0.1.11

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import (Conv2D, Conv2DTranspose,
                          MaxPooling2D, Dropout,
                          concatenate)
from keras import Model
from keras_unet_collection.losses import dice
import os
import glob
from tqdm import tqdm
import cv2 
import matplotlib.pyplot as plt
import numpy as np

# %%
# !rm -rf aug*
import os
import cv2
import random 
import albumentations as A
from numpy import promote_types
from scipy.ndimage import rotate
from skimage import io, img_as_ubyte
from skimage import transform
from skimage.transform import AffineTransform, warp

TOTAL_IMAGES = 180
IMAGE_WIDTH = 320
IMAGE_HEIGHT = int(0.8 * IMAGE_WIDTH)

# IMAGE_HEIGHT = 384
# IMAGE_WIDTH = 480
DATA_DIR = "/content/split_data"
TRAIN_IMG_DIR = os.path.join(DATA_DIR, 'train', 'image')
TRAIN_MSK_DIR = os.path.join(DATA_DIR, 'train', 'mask')
VALID_IMG_DIR = os.path.join(DATA_DIR, 'val', 'image')
VALID_MSK_DIR = os.path.join(DATA_DIR, 'val', 'mask')

train_images = [os.path.join(TRAIN_IMG_DIR, i) for i in sorted(os.listdir(TRAIN_IMG_DIR))]
train_masks = [os.path.join(TRAIN_MSK_DIR, i) for i in sorted(os.listdir(TRAIN_MSK_DIR))]
valid_images = [os.path.join(VALID_IMG_DIR, i) for i in sorted(os.listdir(VALID_IMG_DIR))]
valid_masks = [os.path.join(VALID_MSK_DIR, i) for i in sorted(os.listdir(VALID_MSK_DIR))]
aug_train_images = "augmented/train/images"
aug_train_masks = "augmented/train/masks"
aug_valid_images = "augmented/valid/images"
aug_valid_masks = "augmented/valid/masks"

train_transforms = A.Compose([
    A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=35, p=0.6),
    A.ElasticTransform(
        p=0.5, 
        border_mode = cv2.BORDER_CONSTANT, 
        interpolation = cv2.INTER_AREA
    )
])

valid_transforms = A.Compose([
    A.Resize(height=IMAGE_HEIGHT, width=IMAGE_WIDTH),
])

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def augger(images, masks, transform, total, aug_image_path, aug_mask_path):
    i = 1
    # while i <= total:
    for i in tqdm(range(1, total+ 1), total=total):
        number = random.randint(0, len(images)-1)  #PIck a number to select an image & mask
        image = images[number]
        mask = masks[number]
        # print(number)
        # print(image, mask)
        #image=random.choice(images) #Randomly select an image name
        original_image = io.imread(image)
        # original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
        original_mask = io.imread(mask)
        # print(original_image.shape,original_mask.shape)
        # plt.subplot(121)
        # plt.imshow(original_mask)
        # plt.subplot(122)

        clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(8,8))
        original_image = clahe.apply(original_image)
        # print(cl.shape)
        # plt.imshow(cl)
       
        augmented = transform(image=original_image, mask=original_mask)
        transformed_image = augmented['image']
        transformed_mask = augmented['mask']
        
        new_image_path= "augmented_image_%s.png" %(i)
        new_mask_path = "augmented_mask_%s.png" %(i)
        new_image_path = os.path.join(aug_image_path, f"augmented_image_{i}.png")
        new_mask_path = os.path.join(aug_mask_path, f"augmented_mask_{i}.png")
        io.imsave(new_image_path, transformed_image)
        io.imsave(new_mask_path, transformed_mask)
        # break
        # i += 1
    


create_dir(aug_train_images)
create_dir(aug_train_masks)
create_dir(aug_valid_images)
create_dir(aug_valid_masks)

augger(
    images=train_images,
    masks=train_masks,
    transform = train_transforms,
    total=TOTAL_IMAGES,
    aug_image_path = aug_train_images,
    aug_mask_path = aug_train_masks
)
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_1.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_2.png is a low contrast image
#   1%|          | 2/180 [00:00<00:21,  8.28it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_3.png is a low contrast image
#   2%|▏         | 3/180 [00:00<00:28,  6.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_4.png is a low contrast image
#   2%|▏         | 4/180 [00:00<00:32,  5.45it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_5.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_6.png is a low contrast image
#   3%|▎         | 6/180 [00:00<00:27,  6.22it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_7.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_8.png is a low contrast image
#   4%|▍         | 8/180 [00:01<00:25,  6.84it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_9.png is a low contrast image
#   5%|▌         | 9/180 [00:01<00:28,  6.10it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_10.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_11.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_12.png is a low contrast image
#   7%|▋         | 12/180 [00:01<00:17,  9.76it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_13.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_14.png is a low contrast image
#   8%|▊         | 14/180 [00:01<00:23,  7.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_15.png is a low contrast image
#   8%|▊         | 15/180 [00:02<00:25,  6.46it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_16.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_17.png is a low contrast image
#   9%|▉         | 17/180 [00:02<00:23,  6.79it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_18.png is a low contrast image
#  10%|█         | 18/180 [00:02<00:26,  6.11it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_19.png is a low contrast image
#  11%|█         | 19/180 [00:02<00:28,  5.69it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_20.png is a low contrast image
#  11%|█         | 20/180 [00:03<00:29,  5.41it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_21.png is a low contrast image
#  12%|█▏        | 21/180 [00:03<00:31,  4.99it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_22.png is a low contrast image
#  12%|█▏        | 22/180 [00:03<00:32,  4.87it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_23.png is a low contrast image
#  13%|█▎        | 23/180 [00:03<00:32,  4.86it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_24.png is a low contrast image
#  13%|█▎        | 24/180 [00:04<00:32,  4.85it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_25.png is a low contrast image
#  14%|█▍        | 25/180 [00:04<00:32,  4.81it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_26.png is a low contrast image
#  14%|█▍        | 26/180 [00:04<00:32,  4.73it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_27.png is a low contrast image
#  15%|█▌        | 27/180 [00:04<00:33,  4.62it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_28.png is a low contrast image
#  16%|█▌        | 28/180 [00:04<00:33,  4.60it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_29.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_30.png is a low contrast image
#  17%|█▋        | 30/180 [00:05<00:21,  6.94it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_31.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_32.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_33.png is a low contrast image
#  18%|█▊        | 33/180 [00:05<00:17,  8.32it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_34.png is a low contrast image
#  19%|█▉        | 34/180 [00:05<00:20,  7.04it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_35.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_36.png is a low contrast image
#  20%|██        | 36/180 [00:05<00:20,  7.05it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_37.png is a low contrast image
#  21%|██        | 37/180 [00:06<00:22,  6.33it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_38.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_39.png is a low contrast image
#  22%|██▏       | 39/180 [00:06<00:20,  6.79it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_40.png is a low contrast image
#  22%|██▏       | 40/180 [00:06<00:22,  6.10it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_41.png is a low contrast image
#  23%|██▎       | 41/180 [00:06<00:24,  5.63it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_42.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_43.png is a low contrast image
#  24%|██▍       | 43/180 [00:07<00:21,  6.25it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_44.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_45.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_46.png is a low contrast image
#  26%|██▌       | 46/180 [00:07<00:14,  9.41it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_47.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_48.png is a low contrast image
#  27%|██▋       | 48/180 [00:07<00:15,  8.74it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_49.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_50.png is a low contrast image
#  28%|██▊       | 50/180 [00:07<00:19,  6.75it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_51.png is a low contrast image
#  28%|██▊       | 51/180 [00:08<00:20,  6.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_52.png is a low contrast image
#  29%|██▉       | 52/180 [00:08<00:21,  5.83it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_53.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_54.png is a low contrast image
#  30%|███       | 54/180 [00:08<00:20,  6.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_55.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_56.png is a low contrast image
#  31%|███       | 56/180 [00:08<00:18,  6.71it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_57.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_58.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_59.png is a low contrast image
#  33%|███▎      | 59/180 [00:08<00:12,  9.78it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_60.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_61.png is a low contrast image
#  34%|███▍      | 61/180 [00:09<00:12,  9.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_62.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_63.png is a low contrast image
#  35%|███▌      | 63/180 [00:09<00:13,  8.63it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_64.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_65.png is a low contrast image
#  36%|███▌      | 65/180 [00:09<00:13,  8.40it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_66.png is a low contrast image
#  37%|███▋      | 66/180 [00:09<00:15,  7.37it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_67.png is a low contrast image
#  37%|███▋      | 67/180 [00:10<00:16,  6.72it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_68.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_69.png is a low contrast image
#  38%|███▊      | 69/180 [00:10<00:16,  6.91it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_70.png is a low contrast image
#  39%|███▉      | 70/180 [00:10<00:17,  6.22it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_71.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_72.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_73.png is a low contrast image
#  41%|████      | 73/180 [00:10<00:13,  7.77it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_74.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_75.png is a low contrast image
#  42%|████▏     | 75/180 [00:11<00:13,  7.64it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_76.png is a low contrast image
#  42%|████▏     | 76/180 [00:11<00:14,  6.98it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_77.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_78.png is a low contrast image
#  43%|████▎     | 78/180 [00:11<00:14,  7.25it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_79.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_80.png is a low contrast image
#  44%|████▍     | 80/180 [00:11<00:13,  7.50it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_81.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_82.png is a low contrast image
#  46%|████▌     | 82/180 [00:12<00:12,  7.60it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_83.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_84.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_85.png is a low contrast image
#  47%|████▋     | 85/180 [00:12<00:11,  8.35it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_86.png is a low contrast image
#  48%|████▊     | 86/180 [00:12<00:12,  7.34it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_87.png is a low contrast image
#  48%|████▊     | 87/180 [00:12<00:14,  6.63it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_88.png is a low contrast image
#  49%|████▉     | 88/180 [00:13<00:15,  6.07it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_89.png is a low contrast image
#  49%|████▉     | 89/180 [00:13<00:15,  5.73it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_90.png is a low contrast image
#  50%|█████     | 90/180 [00:13<00:16,  5.33it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_91.png is a low contrast image
#  51%|█████     | 91/180 [00:13<00:17,  5.09it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_92.png is a low contrast image
#  51%|█████     | 92/180 [00:13<00:17,  4.95it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_93.png is a low contrast image
#  52%|█████▏    | 93/180 [00:14<00:18,  4.62it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_94.png is a low contrast image
#  52%|█████▏    | 94/180 [00:14<00:18,  4.55it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_95.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_96.png is a low contrast image
#  53%|█████▎    | 96/180 [00:14<00:15,  5.57it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_97.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_98.png is a low contrast image
#  54%|█████▍    | 98/180 [00:15<00:13,  6.07it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_99.png is a low contrast image
#  55%|█████▌    | 99/180 [00:15<00:14,  5.59it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_100.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_101.png is a low contrast image
#  56%|█████▌    | 101/180 [00:15<00:13,  5.87it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_102.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_103.png is a low contrast image
#  57%|█████▋    | 103/180 [00:15<00:12,  6.26it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_104.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_105.png is a low contrast image
#  58%|█████▊    | 105/180 [00:16<00:11,  6.65it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_106.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_107.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_108.png is a low contrast image
#  60%|██████    | 108/180 [00:16<00:09,  7.87it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_109.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_110.png is a low contrast image
#  61%|██████    | 110/180 [00:16<00:08,  7.89it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_111.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_112.png is a low contrast image
#  62%|██████▏   | 112/180 [00:16<00:07,  9.40it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_113.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_114.png is a low contrast image
#  63%|██████▎   | 114/180 [00:17<00:07,  8.77it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_115.png is a low contrast image
#  64%|██████▍   | 115/180 [00:17<00:08,  7.66it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_116.png is a low contrast image
#  64%|██████▍   | 116/180 [00:17<00:09,  6.89it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_117.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_118.png is a low contrast image
#  66%|██████▌   | 118/180 [00:17<00:08,  7.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_119.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_120.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_121.png is a low contrast image
#  67%|██████▋   | 121/180 [00:17<00:07,  8.29it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_122.png is a low contrast image
#  68%|██████▊   | 122/180 [00:18<00:08,  7.22it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_123.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_124.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_125.png is a low contrast image
#  69%|██████▉   | 125/180 [00:18<00:05,  9.78it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_126.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_127.png is a low contrast image
#  71%|███████   | 127/180 [00:18<00:05,  8.92it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_128.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_129.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_130.png is a low contrast image
#  72%|███████▏  | 130/180 [00:18<00:05,  9.28it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_131.png is a low contrast image
#  73%|███████▎  | 131/180 [00:19<00:06,  8.04it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_132.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_133.png is a low contrast image
#  74%|███████▍  | 133/180 [00:19<00:05,  8.00it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_134.png is a low contrast image
#  74%|███████▍  | 134/180 [00:19<00:06,  7.14it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_135.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_136.png is a low contrast image
#  76%|███████▌  | 136/180 [00:19<00:06,  7.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_137.png is a low contrast image
#  76%|███████▌  | 137/180 [00:20<00:06,  6.39it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_138.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_139.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_140.png is a low contrast image
#  78%|███████▊  | 140/180 [00:20<00:05,  7.46it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_141.png is a low contrast image
#  78%|███████▊  | 141/180 [00:20<00:05,  6.75it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_142.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_143.png is a low contrast image
#  79%|███████▉  | 143/180 [00:20<00:05,  7.01it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_144.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_145.png is a low contrast image
#  81%|████████  | 145/180 [00:21<00:03,  8.86it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_146.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_147.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_148.png is a low contrast image
#  82%|████████▏ | 148/180 [00:21<00:03,  9.38it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_149.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_150.png is a low contrast image
#  83%|████████▎ | 150/180 [00:21<00:04,  7.31it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_151.png is a low contrast image
#  84%|████████▍ | 151/180 [00:21<00:04,  6.60it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_152.png is a low contrast image
#  84%|████████▍ | 152/180 [00:22<00:04,  6.22it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_153.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_154.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_155.png is a low contrast image
#  86%|████████▌ | 155/180 [00:22<00:02,  9.27it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_156.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_157.png is a low contrast image
#  87%|████████▋ | 157/180 [00:22<00:03,  7.27it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_158.png is a low contrast image
#  88%|████████▊ | 158/180 [00:22<00:03,  6.50it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_159.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_160.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_161.png is a low contrast image
#  89%|████████▉ | 161/180 [00:23<00:02,  7.80it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_162.png is a low contrast image
#  90%|█████████ | 162/180 [00:23<00:02,  6.88it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_163.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_164.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_165.png is a low contrast image
#  92%|█████████▏| 165/180 [00:23<00:01,  9.50it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_166.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_167.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_168.png is a low contrast image
#  93%|█████████▎| 168/180 [00:23<00:01, 11.92it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_169.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_170.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_171.png is a low contrast image
#  95%|█████████▌| 171/180 [00:24<00:00, 11.24it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_172.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_173.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_174.png is a low contrast image
#  97%|█████████▋| 174/180 [00:24<00:00, 13.37it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_175.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_176.png is a low contrast image
#  98%|█████████▊| 176/180 [00:24<00:00, 11.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_177.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_178.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_179.png is a low contrast image
#  99%|█████████▉| 179/180 [00:24<00:00, 13.83it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: UserWarning: augmented/train/masks/augmented_mask_180.png is a low contrast image
# 100%|██████████| 180/180 [00:24<00:00,  7.27it/s]

# %%
IMAGE_WIDTH = 320
IMAGE_HEIGHT = int(0.8 * IMAGE_WIDTH)
TRAIN_IMG_DIR = "/content/augmented/train/images"
TRAIN_MSK_DIR = "/content/augmented/train/masks"
#### LOAD DATA
train_images = []
train_masks = []
images_paths = sorted([os.path.join(TRAIN_IMG_DIR, i) for i in os.listdir(TRAIN_IMG_DIR)])
masks_paths = sorted([os.path.join(TRAIN_MSK_DIR, i) for i in os.listdir(TRAIN_MSK_DIR)])
for i, (X,Y) in tqdm(enumerate(zip(images_paths, masks_paths)), total=len(images_paths)):
    img = cv2.imread(X, 0)
    mask = cv2.imread(Y, 0)
    mask = np.where(mask > 0, 255, mask)
    train_images.append(img)
    train_masks.append(mask)
    # plt.subplot(121)
    # plt.imshow(mask)
    # plt.subplot(122)
    # plt.imshow(img)
    # print(img.shape, mask.shape)
    # break
train_images = np.array(train_images, dtype=np.float32)/255.0
train_masks = np.array(train_masks, dtype=np.float32)/255.0
# Out:
# 100%|██████████| 180/180 [00:00<00:00, 589.70it/s]

# %%
X = train_images
Y = train_masks
print(X.shape, Y.shape)
X = np.expand_dims(X, axis=3)
Y = np.expand_dims(Y, axis=3)
print(X.shape, Y.shape)
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)
# Out:
# (180, 256, 320) (180, 256, 320)
# (180, 256, 320, 1) (180, 256, 320, 1)

# %%
from simple_unet import define_model

# %%
define_model??

# %%
from keras_unet_collection.losses import dice_coef
model = define_model(1, IMAGE_HEIGHT, IMAGE_WIDTH, 1)
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=[dice_coef]
)

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
checkpoint = ModelCheckpoint('model_unet_cell_seg_v2.h5', save_best_only=True)

# %%
# !mkdir -p /content/logs/fit
tb = TensorBoard(log_dir='logs/fit/', histogram_freq=1)

# %%
history = model.fit(
    x = x_train, 
    y = y_train,
    batch_size = 8,
    epochs = 30,
    validation_data = (x_val, y_val),
    shuffle = False,
    callbacks = [tb, checkpoint])
# Out:
# Epoch 1/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.1073 - dice_coef: 0.8504 - val_loss: 0.1106 - val_dice_coef: 0.8550
# Epoch 2/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.1062 - dice_coef: 0.8533 - val_loss: 0.1084 - val_dice_coef: 0.8563
# Epoch 3/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.1063 - dice_coef: 0.8531 - val_loss: 0.1100 - val_dice_coef: 0.8575
# Epoch 4/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.1024 - dice_coef: 0.8568 - val_loss: 0.1052 - val_dice_coef: 0.8612
# Epoch 5/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.1025 - dice_coef: 0.8583 - val_loss: 0.1050 - val_dice_coef: 0.8527
# Epoch 6/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0970 - dice_coef: 0.8631 - val_loss: 0.1039 - val_dice_coef: 0.8589
# Epoch 7/30
# 18/18 [==============================] - 45s 3s/step - loss: 0.0930 - dice_coef: 0.8687 - val_loss: 0.1041 - val_dice_coef: 0.8607
# Epoch 8/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0895 - dice_coef: 0.8746 - val_loss: 0.0995 - val_dice_coef: 0.8759
# Epoch 9/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0881 - dice_coef: 0.8766 - val_loss: 0.0984 - val_dice_coef: 0.8786
# Epoch 10/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0857 - dice_coef: 0.8787 - val_loss: 0.0950 - val_dice_coef: 0.8889
# Epoch 11/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0808 - dice_coef: 0.8877 - val_loss: 0.0926 - val_dice_coef: 0.8876
# Epoch 12/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0786 - dice_coef: 0.8907 - val_loss: 0.0966 - val_dice_coef: 0.8813
# Epoch 13/30
# 18/18 [==============================] - 44s 2s/step - loss: 0.0765 - dice_coef: 0.8931 - val_loss: 0.0983 - val_dice_coef: 0.8767
# Epoch 14/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0731 - dice_coef: 0.8972 - val_loss: 0.0912 - val_dice_coef: 0.8905
# Epoch 15/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0746 - dice_coef: 0.8944 - val_loss: 0.0935 - val_dice_coef: 0.8915
# Epoch 16/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0780 - dice_coef: 0.8956 - val_loss: 0.1055 - val_dice_coef: 0.8381
# Epoch 17/30
# 18/18 [==============================] - 44s 2s/step - loss: 0.0899 - dice_coef: 0.8715 - val_loss: 0.0942 - val_dice_coef: 0.8764
# Epoch 18/30
# 18/18 [==============================] - 45s 3s/step - loss: 0.0766 - dice_coef: 0.8922 - val_loss: 0.0886 - val_dice_coef: 0.8918
# Epoch 19/30
# 18/18 [==============================] - 45s 3s/step - loss: 0.0731 - dice_coef: 0.8985 - val_loss: 0.0935 - val_dice_coef: 0.8814
# Epoch 20/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0681 - dice_coef: 0.9049 - val_loss: 0.0916 - val_dice_coef: 0.8858
# Epoch 21/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0647 - dice_coef: 0.9105 - val_loss: 0.0969 - val_dice_coef: 0.8884
# Epoch 22/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0671 - dice_coef: 0.9058 - val_loss: 0.0879 - val_dice_coef: 0.8923
# Epoch 23/30
# 18/18 [==============================] - 45s 3s/step - loss: 0.0687 - dice_coef: 0.9055 - val_loss: 0.1045 - val_dice_coef: 0.8733
# Epoch 24/30
# 18/18 [==============================] - 46s 3s/step - loss: 0.0614 - dice_coef: 0.9136 - val_loss: 0.0877 - val_dice_coef: 0.8985
# Epoch 25/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0565 - dice_coef: 0.9220 - val_loss: 0.0885 - val_dice_coef: 0.9040
# Epoch 26/30
# 18/18 [==============================] - 44s 2s/step - loss: 0.0548 - dice_coef: 0.9238 - val_loss: 0.0891 - val_dice_coef: 0.9036
# Epoch 27/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0553 - dice_coef: 0.9235 - val_loss: 0.0889 - val_dice_coef: 0.9037
# Epoch 28/30
# 18/18 [==============================] - 44s 3s/step - loss: 0.0531 - dice_coef: 0.9260 - val_loss: 0.0891 - val_dice_coef: 0.9054
# Epoch 29/30
# 18/18 [==============================] - 44s 2s/step - loss: 0.0517 - dice_coef: 0.9281 - val_loss: 0.0904 - val_dice_coef: 0.9078
# Epoch 30/30
# 18/18 [==============================] - 44s 2s/step - loss: 0.0539 - dice_coef: 0.9250 - val_loss: 0.1023 - val_dice_coef: 0.9046

# %%
model.save('Neuroblastoma_v1_320x288_e-45_bs-8.h5')
# !cp Neuroblastoma_v1_320x288_e-45_bs-8.h5 /content/drive/MyDrive/Cell_seg/

# %%
# !tensorboard dev upload \
  --logdir logs/fit \
  --name "Neuroblastoma_v1_320x288_e-45_bs-8" \
  --description " dice coef of 0.9250 bruh" \
  --one_shot
# Out:
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# logs/fit
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Continue? (yes/NO) yes
#
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=373649185512-8v619h5kft38l4456nm2dj4ubeqsrvh6.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&state=oFmatP3kFyyh8aEqePMqVz3nCkVKXA&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AX4XfWhdlWkpAKgBIKfRzOAjioK9bUlLFSIut8O_1dV5ubguhy_5NSQWhjI
#
#
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/oLSRm5c7SGK6XC3YzYWblA/
#
# [2021-12-11T13:54:29] Started scanning logdir.
# E1211 13:54:30.646606 140331176761216 uploader.py:1122] Attempted to re-upload existing blob.  Skipping.
# E1211 13:54:31.645609 140331176761216 uploader.py:1122] Attempted to re-upload existing blob.  Skipping.
# [2021-12-11T13:54:33] Total uploaded: 360 scalars, 2760 tensors (1.9 MB), 1 binary objects (170.4 kB)
# Total skipped: 2 binary objects (348.8 kB)
# [2021-12-11T13:54:33] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/oLSRm5c7SGK6XC3YzYWblA/

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'dice_coef', 'val_loss', 'val_dice_coef'])

# %%
X = np.arange(45)
plt.rcParams['figure.figsize'] = (18,15)

for i,m in enumerate([221,222, 223, 224]):
    plt.subplot(m)
    plt.plot(history.history[list(history.history.keys())[i]])
    plt.ylabel(list(history.history.keys())[i])
    plt.xlabel('epoch')
plt.show()

# %%
x_test, y_test = [], []
test_img = "/content/split_data/val/image" 
test_msk = "/content/split_data/val/mask"
test_images = sorted([os.path.join(test_img, i) for i in os.listdir(test_img)])
test_masks = sorted([os.path.join(test_msk, i) for i in os.listdir(test_msk)])

for i, (x, y) in tqdm(enumerate(zip(test_images, test_masks)), total=len(test_images)):
    # original_image = io.imread(x)
    # original_mask = io.imread(y)
    original_image = io.imread(x)
    # original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
    original_mask = io.imread(y)
    clahe = cv2.createCLAHE(clipLimit=8.0, tileGridSize=(8,8))
    original_image = clahe.apply(original_image)
    original_mask = np.where(original_mask > 0, 255, original_mask)
    augmented = valid_transforms(image=original_image, mask=original_mask)
    transformed_image = augmented['image']
    transformed_mask = augmented['mask']
    # transformed_mask = np.where(transformed_mask > 0, 255, transformed_mask)
    # transformed_image = transformed_image.astype(np.float32)
    # transformed_mask = transformed_mask.astype(np.float32)
    x_test.append(transformed_image)
    y_test.append(transformed_mask)

    # plt.subplot(121)
    # plt.imshow(transformed_image)
    # plt.subplot(122)
    # plt.imshow(transformed_mask)
    # break
x_test = np.array(x_test, dtype=np.float32)/255.0
y_test = np.array(y_test, dtype=np.float32)/255.0
x_test = np.expand_dims(x_test, axis = 3)
y_test = np.expand_dims(y_test, axis = 3)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 63.69it/s]

# %%
preds = model.predict(x_test, batch_size=8)

# %%
import random
i = random.randint(0,len(preds)-1)
i=2
plt.subplot(131)
plt.imshow(np.reshape(np.where(preds[i] > 0.05, 255, 0), (IMAGE_HEIGHT, IMAGE_WIDTH)))
# plt.imshow(np.reshape(preds[i] , (IMAGE_HEIGHT, IMAGE_WIDTH)))
plt.subplot(132)
plt.imshow(np.reshape(y_test[i] , (IMAGE_HEIGHT, IMAGE_WIDTH)))
plt.subplot(133)
plt.imshow(np.reshape(x_test[i] , (IMAGE_HEIGHT, IMAGE_WIDTH)))
plt.savefig("/content/drive/MyDrive/Cell_seg/Neuroblastoma.png")
print(i, dice_coef(preds[i], y_test[i]))
# Out:
# 2 tf.Tensor(0.9182024, shape=(), dtype=float32)
